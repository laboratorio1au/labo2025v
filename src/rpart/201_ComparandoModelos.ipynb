# %% [markdown]
# <a href="https://colab.research.google.com/github/laboratorio1au/labo2025v/blob/main/src/rpart/201_ComparandoModelos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comparando Modelos

# %% [markdown]
# Estamos en la  Clase 02
# <br> El objetivo de la materia es lograr la mejor predicción para nuestro probleama, para lo que se probarán pipelines con decenas de alternativas, será indispensable comparar varios modelos predictivos entre sí y decidir cual es el mejor
# <br> La tarea no es tan sencilla

# %% [markdown]
# ## Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Drive already mounted at /content/.drive; to attempt to forcibly remount, call drive.mount("/content/.drive", force_remount=True).

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi
# Out:
# ln: failed to create symbolic link '/content/buckets/b1/labo1': File exists
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# # 1  Particion Training/Testing
# ## Clase 02  Experimento 1

# %% [markdown]
# ## 1.1  Objetivos
# Dado que es el primer experimento de la asignatura, acercar a l@s estudiantes las mejores prácticas de operación del ambiente de Google Cloud, realizando una minuciosa demostración en vivo narrando todas las consideraciones pertinentes para evitar accidentes, daños a terceros y a equipos.
# Dar soporte en el acto a  l@s estudiantes que necesitan ayuda para terminar de configurar el ambiente Google Cloud .
# <br>Repaso del concepto de  partición de un dataset al azar, estratificada en la clase
# <br>Dado que es el primer script que se mostrará en vivo a l@s estudiantes,  realizar una visita guiada del  mismo, su estructura y detalles.
# <br>Repaso del algoritmo Arbol de Decisión sus hiperparámetros, y la implementación con la librería  rpart.  Funciones  rpart::rpart  y rpart::predict
# <br>Concepto de replicabilidad de los experimentos mediante las semillas de los generadores de secuencias de números pseudoaleatorios.
# <br>Finalmente, el principal objetivo de este experimento es lograr que l@s estudiantes dimensionen la enorme variabilidad del error de medición de la ganancia de un árbol de decisión al realizar una partición <training, testing>,  contener la sorpresa de los estudiantes, descartar a la simple particion <training, testing> como método,  y construir en conjunto una solucion natural al problema.

# %% [markdown]
# ## 1.2 Introduccion

# %% [markdown]
# ![Particiohn Training/Testing](https://storage.googleapis.com/open-courses/austral2025-af91/labo1r/C2_E1_particion.jpg)

# %% [markdown]
# ![Dos tipos de error](https://storage.googleapis.com/open-courses/austral2025-af91/labo1r/C2_E1_target.jpg)

# %% [markdown]
# ## 1.3  Bibliografía
#
# Demšar, J. [Statistical comparisons of classifiers over multiple data sets](https://www.jmlr.org/papers/volume7/demsar06a/demsar06a.pdf) J. Mach. Learn. Res. 7, 1–30 (2006).
# Starmer, J. [Machine Learning Fundamentals: Cross Validation](https://www.youtube.com/watch?v=fSytzGwwBVw)Machine Learning Fundamentals: Cross Validation, StatQuest with Josh Starmer youtube channel, (2018)
# Hastie, T.[The elements of statistical learning: data mining, inference, and prediction](https://hastie.su.domains/Papers/ESLII.pdf) , volume 2. Springer, 2009  ( Chapter 7 Model Assessment and Selection )

# %% [markdown]
# ## 1.4 Codigo

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  657218 35.1 1454505    77.7 1325428  70.8
# Vcells 1220160  9.4 8388608    64.0 1975136  15.1

# %%
Sys.time()
# Out:
# [1] "2025-12-02 10:40:52 UTC"

# %% [markdown]
# * Instalacion de la libreria  rpart.plot  para dibujar el arbol
# * invocacion de las librerias  **data.table** y  **rpart**

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
# Out:
# Loading required package: data.table
#
# Loading required package: rpart

# %% [markdown]
# ###  Accion a Realizar
# PARAM$semilla  debe tener su primer semilla aleatoria

# %%
PARAM <- list()
PARAM$semilla <- 104729  # aqui debe ir su primer semilla
PARAM$training_pct <- 70L  # entre  1L y 99L

PARAM$rpart <- list (
  "cp" = -1, # complejidad minima
  "minsplit" = 170, # minima cantidad de regs en un nodo para hacer el split
  "minbucket" = 70, # minima cantidad de regs en una hoja
  "maxdepth" = 7 # profundidad máxima del arbol
)

# %%
# particionar agrega una columna llamada fold a un dataset
#  que consiste en una particion estratificada segun agrupa

# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(
    data, division, agrupa = "",
    campo = "fold", start = 1, seed = NA) {
  if (!is.na(seed)) set.seed(seed)

  bloque <- unlist(mapply(function(x, y) {
    rep(y, x)
  }, division, seq(from = start, length.out = length(division))))

  data[, (campo) := sample(rep(bloque, ceiling(.N / length(bloque))))[1:.N],
    by = agrupa
  ]
}

# %%
# carpeta de trabajo
setwd("/content/buckets/b1/exp")
experimento <- "exp201"
dir.create(experimento, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %%
# lectura del dataset
dataset <- fread("/content/datasets/dataset_pequeno.csv")

# trabajo solo con los datos con clase, es decir 202107
dataset <- dataset[clase_ternaria != ""]

# %%
# particiono estratificadamente el dataset 70%, 30%
particionar(dataset,
  division = c(PARAM$training_pct, 100L -PARAM$training_pct),
  agrupa = "clase_ternaria",
  seed = PARAM$semilla # aqui se usa SU semilla
)

# %%
# genero el modelo
# quiero predecir clase_ternaria a partir del resto
# fold==1  es training,  el 70% de los datos
modelo <- rpart("clase_ternaria ~ .",
  data = dataset[fold == 1],  # fold==1  es training, el 70% de los datos
  xval = 0,
  control = PARAM$rpart # aqui van los parametros
)

# %%
# aplico el modelo a los datos de testing
prediccion <- predict(modelo, # el modelo que genere recien
  dataset[fold == 2], # fold==2  es testing, el 30% de los datos
  type = "prob"
) # type= "prob"  es que devuelva la probabilidad

# %%
tb_prediccion <- as.data.table(list(
  "clase_ternaria"=dataset[fold == 2, clase_ternaria],
  "prob"=prediccion[, "BAJA+2"]
))

# %%
# calculo la ganancia de cada registro
tb_prediccion[, ganancia := ifelse(clase_ternaria == "BAJA+2", 117000, -3000)]

# %%
# calculo la clase
tb_prediccion[, Predicted := prob > (1/40) ]

# %%
ganancia_test <-  tb_prediccion[ Predicted==TRUE,  sum(ganancia)]

# %%
# normalizo la ganancia
ganancia_test_normalizada <- ganancia_test / (( 100 - PARAM$training_pct ) / 100 )

# %%
estimulos <- tb_prediccion[ Predicted==TRUE, .N]
aciertos <- tb_prediccion[ Predicted & clase_ternaria == "BAJA+2", .N]

# %%
# Resultado Final
cat("Testing total: ", dataset[fold == 2, .N], "\n")
cat("Testing BAJA+2: ", dataset[fold == 2 & clase_ternaria == "BAJA+2", .N], "\n")

cat("Estimulos: ", estimulos, "\n")
cat("Aciertos (BAJA+2): ", aciertos, "\n")

cat("Ganancia en testing (normalizada): ", ganancia_test_normalizada, "\n")
# Out:
# Testing total:  49386
# Testing BAJA+2:  378
# Estimulos:  3311
# Aciertos (BAJA+2):  197
# Ganancia en testing (normalizada):  45690000

# %% [markdown]
# ### Acciones a realizar
# * Reportar la  *Ganancia en testing (normalizada)* <br> en la planilla colaborativa hoja  **C2-1sem**
# * Se discutirá en clase la variabilidad de las ganancias obtenidas de distintos alumnos

# %% [markdown]
# ---

# %% [markdown]
# # 2  Medición Monte Carlo Cross Validation
# ## Clase 02  Experimento 2

# %% [markdown]
# ## 2.1  Objetivos
# Mostrar el funcionamiento de la Montecarlo Cross Validation y que l@s estudiantes aprecien la disminución de la varianza de dicha metodología.
# Relación con el Teorema Central del Límite

# %% [markdown]
# ## 2.2 Introduccion
#
# ![Montecarlo](https://storage.googleapis.com/open-courses/austral2025-af91/labo1r/C2_E2_montecarlo.jpg)
#
# ![Curva normal](https://storage.googleapis.com/open-courses/austral2025-af91/labo1r/C2_E2_normal.jpg)
#
# ![Teorema Central del Limite](https://storage.googleapis.com/open-courses/austral2025-af91/labo1r/C2_E2_teoremacentralLimite.jpg)

# %% [markdown]
# ## 2.3  Bibliografía
#
# Demšar, J. [Statistical comparisons of classifiers over multiple data sets](https://www.jmlr.org/papers/volume7/demsar06a/demsar06a.pdf) J. Mach. Learn. Res. 7, 1–30 (2006).
# Starmer, J. [Machine Learning Fundamentals: Cross Validation](https://www.youtube.com/watch?v=fSytzGwwBVw)Machine Learning Fundamentals: Cross Validation, StatQuest with Josh Starmer youtube channel, (2018)
# Hastie, T.[The elements of statistical learning: data mining, inference, and prediction](https://hastie.su.domains/Papers/ESLII.pdf) , volume 2. Springer, 2009  ( Chapter 7 Model Assessment and Selection )

# %% [markdown]
# ## 2.4 Codigo  Montecarlo

# %% [markdown]
# El código de la Montecarlo Cross Validation es notablemente más complejo que el anterior de una simple partición training/testing
# <br> Se crea la funcion ArbolEstimarGanancia()  que dada una semilla realiza la partición  training/testing, entrena en training, aplica el modelo a testing, y se calculan las ganancias
# <br> Se utiliza la funcion **mcmapply**  de R para aplicar ArbolEstimarGanancia a todos los elementos del vector de semillas

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb)  max used  (Mb)
# Ncells  744882 39.8  1454505    77.7   1454505  77.7
# Vcells 1412126 10.8 84907047   647.8 104193531 795.0

# %% [markdown]
# * Instalacion de la libreria  rpart.plot  para dibujar el arbol
# * invocacion de las librerias  **data.table** y  **rpart**

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
require("parallel")
# Out:
# Loading required package: parallel

# %% [markdown]
# ###  Accion a Realizar
# PARAM$semillas  debe tener sus cinco semillas aleatorias

# %%
PARAM <- list()
PARAM$semillas <- c(102191, 200177, 410551, 552581, 892237)  # aqui debe ir sus CINCO
PARAM$training_pct <- 70L  # entre  1L y 99L

PARAM$rpart <- list (
  "cp" = -1, # complejidad minima
  "minsplit" = 170, # minima cantidad de regs en un nodo para hacer el split
  "minbucket" = 70, # minima cantidad de regs en una hoja
  "maxdepth" = 7 # profundidad máxima del arbol
)

# %%
# particionar agrega una columna llamada fold a un dataset
#  que consiste en una particion estratificada segun agrupa

# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(
    data, division, agrupa = "",
    campo = "fold", start = 1, seed = NA) {
  if (!is.na(seed)) set.seed(seed)

  bloque <- unlist(mapply(function(x, y) {
    rep(y, x)
  }, division, seq(from = start, length.out = length(division))))

  data[, (campo) := sample(rep(bloque, ceiling(.N / length(bloque))))[1:.N],
    by = agrupa
  ]
}

# %%
ArbolEstimarGanancia <- function(semilla, param_basicos) {
  # particiono estratificadamente el dataset
  particionar(dataset,
    division = c(param_basicos$training_pct, 100L -param_basicos$training_pct),
    agrupa = "clase_ternaria",
    seed = semilla # aqui se usa SU semilla
  )

  # genero el modelo
  # predecir clase_ternaria a partir del resto
  modelo <- rpart("clase_ternaria ~ .",
    data = dataset[fold == 1], # fold==1  es training,  el 70% de los datos
    xval = 0,
    control = param_basicos$rpart
  ) # aqui van los parametros del arbol

  # aplico el modelo a los datos de testing
  prediccion <- predict(modelo, # el modelo que genere recien
    dataset[fold == 2], # fold==2  es testing, el 30% de los datos
    type = "prob"
  ) # type= "prob"  es que devuelva la probabilidad

  # prediccion es una matriz con TRES columnas,
  #  llamadas "BAJA+1", "BAJA+2"  y "CONTINUA"
  # cada columna es el vector de probabilidades


  # calculo la ganancia en testing  qu es fold==2
  ganancia_test <- dataset[
    fold == 2,
    sum(ifelse(prediccion[, "BAJA+2"] > 0.025,
      ifelse(clase_ternaria == "BAJA+2", 117000, -3000),
      0
    ))
  ]

  # escalo la ganancia como si fuera todo el dataset
  ganancia_test_normalizada <- ganancia_test / (( 100 - PARAM$training_pct ) / 100 )

  return(list(
    "semilla" = semilla,
    "testing" = dataset[fold == 2, .N],
    "testing_pos" = dataset[fold == 2 & clase_ternaria == "BAJA+2", .N],
    "envios" = dataset[fold == 2, sum(prediccion[, "BAJA+2"] > 0.025)],
    "aciertos" = dataset[
        fold == 2,
        sum(prediccion[, "BAJA+2"] > 0.025 & clase_ternaria == "BAJA+2")
    ],
    "ganancia_test" = ganancia_test_normalizada
  ))
}

# %%
# carpeta de trabajo
setwd("/content/buckets/b1/exp")
experimento <- "exp202"
dir.create(experimento, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %%
# lectura del dataset
dataset <- fread("/content/datasets/dataset_pequeno.csv")

# trabajo solo con los datos con clase, es decir 202107
dataset <- dataset[clase_ternaria != ""]

# %%
# la funcion mcmapply  llama a la funcion ArbolEstimarGanancia
#  tantas veces como valores tenga el vector  PARAM$semillas
salidas <- mcmapply(ArbolEstimarGanancia,
  PARAM$semillas, # paso el vector de semillas
  MoreArgs = list(PARAM), # aqui paso el segundo parametro
  SIMPLIFY = FALSE,
  mc.cores = detectCores()
)

# muestro la lista de las salidas en testing
#  para la particion realizada con cada semilla
salidas
# Out:
# [[1]]
# [[1]]$semilla
# [1] 102191
#
# [[1]]$testing
# [1] 49373
#
# [[1]]$testing_pos
# [1] 377
#
# [[1]]$envios
# [1] 3766
#
# [[1]]$aciertos
# [1] 223
#
# [[1]]$ganancia_test
# [1] 51540000
#
#
# [[2]]
# [[2]]$semilla
# [1] 200177
#
# [[2]]$testing
# [1] 49369
#
# [[2]]$testing_pos
# [1] 368
#
# [[2]]$envios
# [1] 3674
#
# [[2]]$aciertos
# [1] 204
#
# [[2]]$ganancia_test
# [1] 44860000
#
#
# [[3]]
# [[3]]$semilla
# [1] 410551
#
# [[3]]$testing
# [1] 49380
#
# [[3]]$testing_pos
# [1] 374
#
# [[3]]$envios
# [1] 3723
#
# [[3]]$aciertos
# [1] 208
#
# [[3]]$ganancia_test
# [1] 45970000
#
#
# [[4]]
# [[4]]$semilla
# [1] 552581
#
# [[4]]$testing
# [1] 49381
#
# [[4]]$testing_pos
# [1] 380
#
# [[4]]$envios
# [1] 3792
#
# [[4]]$aciertos
# [1] 227
#
# [[4]]$ganancia_test
# [1] 52880000
#
#
# [[5]]
# [[5]]$semilla
# [1] 892237
#
# [[5]]$testing
# [1] 49379
#
# [[5]]$testing_pos
# [1] 378
#
# [[5]]$envios
# [1] 3192
#
# [[5]]$aciertos
# [1] 206
#
# [[5]]$ganancia_test
# [1] 50480000

# %%
# paso la lista a vector
tb_salida <- rbindlist(salidas)
print( tb_salida)
# Out:
#    semilla testing testing_pos envios aciertos ganancia_test
#      <num>   <int>       <int>  <int>    <int>         <num>
# 1:  102191   49373         377   3766      223      51540000
# 2:  200177   49369         368   3674      204      44860000
# 3:  410551   49380         374   3723      208      45970000
# 4:  552581   49381         380   3792      227      52880000
# 5:  892237   49379         378   3192      206      50480000

# %%
# finalmente calculo la media (promedio)  de las ganancias
cat( "ganancia promedio: ", tb_salida[, mean(ganancia_test)], "\n" )
# Out:
# ganancia promedio:  49146000

# %% [markdown]
# ### Acciones a realizar
# * Reportar la  *Ganancia Promedio* <br> en la planilla colaborativa hoja  **C2-5sem**
# * Se discutirá en clase la variabilidad de estos "ganancia promedio de cinco semillas"

# %% [markdown]
# ---

# %% [markdown]
# # 3  Generando n semillas en forma automatica
# ## Clase 02  Experimento 3

# %% [markdown]
# ## 3.1  Objetivos
# Mostrar la creación de nuevas semillas a partir de la librería Primes

# %% [markdown]
# 3.2  Código
#
# Como generar muchas semillas a partir de una

# %%
# instalo y cargo la libreria  primes
if (!require("primes")) install.packages("primes")
require("primes")
# Out:
# Loading required package: primes

# %%
# genero numeros primos
primos <- generate_primes(min = 100000, max = 1000000)


set.seed(102191) # inicializo con mi primer semilla

# me quedo con por ejemplo 20 primos al azar
semillas <- sample(primos, 20 )

print( semillas )
# Out:
#  [1] 378821 964333 187049 205151 813697 344719 127217 464371 645137 480803
# [11] 723319 314641 791599 937577 685649 619363 390539 465887 619657 195737

# %% [markdown]
# ---

# %% [markdown]
# # 4  Medición  50-Monte Carlo Cross Validation
# ## Clase 02  Experimento 4

# %% [markdown]
# ## 4.1  Objetivos
# Calcular la ganancia del modelo utilizando 50 semillas nuevas generadas a partir de mi semilla primigenia.

# %% [markdown]
# ## 4.4 Codigo  50 Montecarlo

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %% [markdown]
# Este punto demora en correr 60 minutos en Google Colab, con lo cual para continuar con el punto siguiente deberá abrir un nuevo Colab

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb)  max used  (Mb)
# Ncells  812040 43.4  1454505    77.7   1454505  77.7
# Vcells 1519362 11.6 67925638   518.3 104193531 795.0

# %% [markdown]
# * Instalacion de la libreria  rpart.plot  para dibujar el arbol
# * invocacion de las librerias  **data.table** y  **rpart**

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
require("parallel")

if (!require("primes")) install.packages("primes")
require("primes")

# %% [markdown]
# ###  Accion a Realizar
# PARAM$semilla_primigenia  debe reemplazarse por SU primer semilla

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 104729
PARAM$qsemillas <- 100
PARAM$training_pct <- 70L  # entre  1L y 99L

PARAM$rpart <- list (
  "cp" = -1, # complejidad minima
  "minsplit" = 170, # minima cantidad de regs en un nodo para hacer el split
  "minbucket" = 70, # minima cantidad de regs en una hoja
  "maxdepth" = 7 # profundidad máxima del arbol
)

# %%
# particionar agrega una columna llamada fold a un dataset
#  que consiste en una particion estratificada segun agrupa

# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(
    data, division, agrupa = "",
    campo = "fold", start = 1, seed = NA) {
  if (!is.na(seed)) set.seed(seed)

  bloque <- unlist(mapply(function(x, y) {
    rep(y, x)
  }, division, seq(from = start, length.out = length(division))))

  data[, (campo) := sample(rep(bloque, ceiling(.N / length(bloque))))[1:.N],
    by = agrupa
  ]
}

# %%
ArbolEstimarGanancia <- function(semilla, param_basicos) {
  # particiono estratificadamente el dataset
  particionar(dataset,
    division = c(param_basicos$training_pct, 100L -param_basicos$training_pct),
    agrupa = "clase_ternaria",
    seed = semilla # aqui se usa SU semilla
  )

  # genero el modelo
  # predecir clase_ternaria a partir del resto
  modelo <- rpart("clase_ternaria ~ .",
    data = dataset[fold == 1], # fold==1  es training,  el 70% de los datos
    xval = 0,
    control = param_basicos$rpart
  ) # aqui van los parametros del arbol

  # aplico el modelo a los datos de testing
  prediccion <- predict(modelo, # el modelo que genere recien
    dataset[fold == 2], # fold==2  es testing, el 30% de los datos
    type = "prob"
  ) # type= "prob"  es que devuelva la probabilidad

  # prediccion es una matriz con TRES columnas,
  #  llamadas "BAJA+1", "BAJA+2"  y "CONTINUA"
  # cada columna es el vector de probabilidades


  # calculo la ganancia en testing  qu es fold==2
  ganancia_test <- dataset[
    fold == 2,
    sum(ifelse(prediccion[, "BAJA+2"] > 0.025,
      ifelse(clase_ternaria == "BAJA+2", 117000, -3000),
      0
    ))
  ]

  # escalo la ganancia como si fuera todo el dataset
  ganancia_test_normalizada <- ganancia_test / (( 100 - PARAM$training_pct ) / 100 )

  return(list(
    "semilla" = semilla,
    "testing" = dataset[fold == 2, .N],
    "testing_pos" = dataset[fold == 2 & clase_ternaria == "BAJA+2", .N],
    "envios" = dataset[fold == 2, sum(prediccion[, "BAJA+2"] > 0.025)],
    "aciertos" = dataset[
        fold == 2,
        sum(prediccion[, "BAJA+2"] > 0.025 & clase_ternaria == "BAJA+2")
    ],
    "ganancia_test" = ganancia_test_normalizada
  ))
}

# %%
# carpeta de trabajo
setwd("/content/buckets/b1/exp")
experimento <- "exp204"
dir.create(experimento, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %%
# lectura del dataset
dataset <- fread("/content/datasets/dataset_pequeno.csv")

# trabajo solo con los datos con clase, es decir 202107
dataset <- dataset[clase_ternaria != ""]

# %%
# genero numeros primos
primos <- generate_primes(min = 100000, max = 1000000)
set.seed(PARAM$semilla_primigenia) # inicializo

# me quedo con PARAM$qsemillas   semillas
PARAM$semillas <- sample(primos, PARAM$qsemillas )

# %%
# la funcion mcmapply  llama a la funcion ArbolEstimarGanancia
#  tantas veces como valores tenga el vector  PARAM$semillas
salidas <- mcmapply(ArbolEstimarGanancia,
  PARAM$semillas, # paso el vector de semillas
  MoreArgs = list(PARAM), # aqui paso el segundo parametro
  SIMPLIFY = FALSE,
  mc.cores = detectCores()
)

# muestro la lista de las salidas en testing
#  para la particion realizada con cada semilla
salidas
# Out:
# [[1]]
# [[1]]$semilla
# [1] 452033
#
# [[1]]$testing
# [1] 49384
#
# [[1]]$testing_pos
# [1] 376
#
# [[1]]$envios
# [1] 4024
#
# [[1]]$aciertos
# [1] 222
#
# [[1]]$ganancia_test
# [1] 48560000
#
#
# [[2]]
# [[2]]$semilla
# [1] 855377
#
# [[2]]$testing
# [1] 49376
#
# [[2]]$testing_pos
# [1] 370
#
# [[2]]$envios
# [1] 2180
#
# [[2]]$aciertos
# [1] 154
#
# [[2]]$ganancia_test
# [1] 39800000
#
#
# [[3]]
# [[3]]$semilla
# [1] 214663
#
# [[3]]$testing
# [1] 49370
#
# [[3]]$testing_pos
# [1] 373
#
# [[3]]$envios
# [1] 4019
#
# [[3]]$aciertos
# [1] 219
#
# [[3]]$ganancia_test
# [1] 47410000
#
#
# [[4]]
# [[4]]$semilla
# [1] 842977
#
# [[4]]$testing
# [1] 49372
#
# [[4]]$testing_pos
# [1] 371
#
# [[4]]$envios
# [1] 3322
#
# [[4]]$aciertos
# [1] 192
#
# [[4]]$ganancia_test
# [1] 43580000
#
#
# [[5]]
# [[5]]$semilla
# [1] 764657
#
# [[5]]$testing
# [1] 49383
#
# [[5]]$testing_pos
# [1] 371
#
# [[5]]$envios
# [1] 3596
#
# [[5]]$aciertos
# [1] 202
#
# [[5]]$ganancia_test
# [1] 44840000
#
#
# [[6]]
# [[6]]$semilla
# [1] 141079
#
# [[6]]$testing
# [1] 49378
#
# [[6]]$testing_pos
# [1] 375
#
# [[6]]$envios
# [1] 4497
#
# [[6]]$aciertos
# [1] 230
#
# [[6]]$ganancia_test
# [1] 47030000
#
#
# [[7]]
# [[7]]$semilla
# [1] 549547
#
# [[7]]$testing
# [1] 49381
#
# [[7]]$testing_pos
# [1] 376
#
# [[7]]$envios
# [1] 3888
#
# [[7]]$aciertos
# [1] 195
#
# [[7]]$ganancia_test
# [1] 39120000
#
#
# [[8]]
# [[8]]$semilla
# [1] 431777
#
# [[8]]$testing
# [1] 49395
#
# [[8]]$testing_pos
# [1] 384
#
# [[8]]$envios
# [1] 3261
#
# [[8]]$aciertos
# [1] 194
#
# [[8]]$ganancia_test
# [1] 44990000
#
#
# [[9]]
# [[9]]$semilla
# [1] 781283
#
# [[9]]$testing
# [1] 49369
#
# [[9]]$testing_pos
# [1] 370
#
# [[9]]$envios
# [1] 2935
#
# [[9]]$aciertos
# [1] 193
#
# [[9]]$ganancia_test
# [1] 47850000
#
#
# [[10]]
# [[10]]$semilla
# [1] 585461
#
# [[10]]$testing
# [1] 49377
#
# [[10]]$testing_pos
# [1] 373
#
# [[10]]$envios
# [1] 4097
#
# [[10]]$aciertos
# [1] 224
#
# [[10]]$ganancia_test
# [1] 48630000
#
#
# [[11]]
# [[11]]$semilla
# [1] 748597
#
# [[11]]$testing
# [1] 49401
#
# [[11]]$testing_pos
# [1] 381
#
# [[11]]$envios
# [1] 3929
#
# [[11]]$aciertos
# [1] 219
#
# [[11]]$ganancia_test
# [1] 48310000
#
#
# [[12]]
# [[12]]$semilla
# [1] 595379
#
# [[12]]$testing
# [1] 49377
#
# [[12]]$testing_pos
# [1] 374
#
# [[12]]$envios
# [1] 3203
#
# [[12]]$aciertos
# [1] 193
#
# [[12]]$ganancia_test
# [1] 45170000
#
#
# [[13]]
# [[13]]$semilla
# [1] 802183
#
# [[13]]$testing
# [1] 49378
#
# [[13]]$testing_pos
# [1] 370
#
# [[13]]$envios
# [1] 3715
#
# [[13]]$aciertos
# [1] 203
#
# [[13]]$ganancia_test
# [1] 44050000
#
#
# [[14]]
# [[14]]$semilla
# [1] 225149
#
# [[14]]$testing
# [1] 49379
#
# [[14]]$testing_pos
# [1] 371
#
# [[14]]$envios
# [1] 2751
#
# [[14]]$aciertos
# [1] 192
#
# [[14]]$ganancia_test
# [1] 49290000
#
#
# [[15]]
# [[15]]$semilla
# [1] 225241
#
# [[15]]$testing
# [1] 49393
#
# [[15]]$testing_pos
# [1] 379
#
# [[15]]$envios
# [1] 3278
#
# [[15]]$aciertos
# [1] 221
#
# [[15]]$ganancia_test
# [1] 55620000
#
#
# [[16]]
# [[16]]$semilla
# [1] 379459
#
# [[16]]$testing
# [1] 49376
#
# [[16]]$testing_pos
# [1] 379
#
# [[16]]$envios
# [1] 4185
#
# [[16]]$aciertos
# [1] 233
#
# [[16]]$ganancia_test
# [1] 51350000
#
#
# [[17]]
# [[17]]$semilla
# [1] 992521
#
# [[17]]$testing
# [1] 49366
#
# [[17]]$testing_pos
# [1] 373
#
# [[17]]$envios
# [1] 4385
#
# [[17]]$aciertos
# [1] 211
#
# [[17]]$ganancia_test
# [1] 40550000
#
#
# [[18]]
# [[18]]$semilla
# [1] 333031
#
# [[18]]$testing
# [1] 49380
#
# [[18]]$testing_pos
# [1] 379
#
# [[18]]$envios
# [1] 4164
#
# [[18]]$aciertos
# [1] 223
#
# [[18]]$ganancia_test
# [1] 47560000
#
#
# [[19]]
# [[19]]$semilla
# [1] 233341
#
# [[19]]$testing
# [1] 49381
#
# [[19]]$testing_pos
# [1] 380
#
# [[19]]$envios
# [1] 3748
#
# [[19]]$aciertos
# [1] 214
#
# [[19]]$ganancia_test
# [1] 48120000
#
#
# [[20]]
# [[20]]$semilla
# [1] 519287
#
# [[20]]$testing
# [1] 49386
#
# [[20]]$testing_pos
# [1] 376
#
# [[20]]$envios
# [1] 2981
#
# [[20]]$aciertos
# [1] 179
#
# [[20]]$ganancia_test
# [1] 41790000
#
#
# [[21]]
# [[21]]$semilla
# [1] 357587
#
# [[21]]$testing
# [1] 49380
#
# [[21]]$testing_pos
# [1] 373
#
# [[21]]$envios
# [1] 3684
#
# [[21]]$aciertos
# [1] 229
#
# [[21]]$ganancia_test
# [1] 54760000
#
#
# [[22]]
# [[22]]$semilla
# [1] 230431
#
# [[22]]$testing
# [1] 49374
#
# [[22]]$testing_pos
# [1] 379
#
# [[22]]$envios
# [1] 2589
#
# [[22]]$aciertos
# [1] 174
#
# [[22]]$ganancia_test
# [1] 43710000
#
#
# [[23]]
# [[23]]$semilla
# [1] 504947
#
# [[23]]$testing
# [1] 49374
#
# [[23]]$testing_pos
# [1] 375
#
# [[23]]$envios
# [1] 3588
#
# [[23]]$aciertos
# [1] 209
#
# [[23]]$ganancia_test
# [1] 47720000
#
#
# [[24]]
# [[24]]$semilla
# [1] 930689
#
# [[24]]$testing
# [1] 49378
#
# [[24]]$testing_pos
# [1] 377
#
# [[24]]$envios
# [1] 3230
#
# [[24]]$aciertos
# [1] 213
#
# [[24]]$ganancia_test
# [1] 52900000
#
#
# [[25]]
# [[25]]$semilla
# [1] 742439
#
# [[25]]$testing
# [1] 49377
#
# [[25]]$testing_pos
# [1] 371
#
# [[25]]$envios
# [1] 3265
#
# [[25]]$aciertos
# [1] 217
#
# [[25]]$ganancia_test
# [1] 54150000
#
#
# [[26]]
# [[26]]$semilla
# [1] 361873
#
# [[26]]$testing
# [1] 49378
#
# [[26]]$testing_pos
# [1] 373
#
# [[26]]$envios
# [1] 3359
#
# [[26]]$aciertos
# [1] 191
#
# [[26]]$ganancia_test
# [1] 42810000
#
#
# [[27]]
# [[27]]$semilla
# [1] 219503
#
# [[27]]$testing
# [1] 49375
#
# [[27]]$testing_pos
# [1] 373
#
# [[27]]$envios
# [1] 3965
#
# [[27]]$aciertos
# [1] 206
#
# [[27]]$ganancia_test
# [1] 42750000
#
#
# [[28]]
# [[28]]$semilla
# [1] 922289
#
# [[28]]$testing
# [1] 49365
#
# [[28]]$testing_pos
# [1] 371
#
# [[28]]$envios
# [1] 4197
#
# [[28]]$aciertos
# [1] 213
#
# [[28]]$ganancia_test
# [1] 43230000
#
#
# [[29]]
# [[29]]$semilla
# [1] 978403
#
# [[29]]$testing
# [1] 49383
#
# [[29]]$testing_pos
# [1] 375
#
# [[29]]$envios
# [1] 2568
#
# [[29]]$aciertos
# [1] 193
#
# [[29]]$ganancia_test
# [1] 51520000
#
#
# [[30]]
# [[30]]$semilla
# [1] 453667
#
# [[30]]$testing
# [1] 49376
#
# [[30]]$testing_pos
# [1] 378
#
# [[30]]$envios
# [1] 4093
#
# [[30]]$aciertos
# [1] 206
#
# [[30]]$ganancia_test
# [1] 41470000
#
#
# [[31]]
# [[31]]$semilla
# [1] 435553
#
# [[31]]$testing
# [1] 49382
#
# [[31]]$testing_pos
# [1] 371
#
# [[31]]$envios
# [1] 2833
#
# [[31]]$aciertos
# [1] 194
#
# [[31]]$ganancia_test
# [1] 49270000
#
#
# [[32]]
# [[32]]$semilla
# [1] 245131
#
# [[32]]$testing
# [1] 49388
#
# [[32]]$testing_pos
# [1] 373
#
# [[32]]$envios
# [1] 3352
#
# [[32]]$aciertos
# [1] 199
#
# [[32]]$ganancia_test
# [1] 46080000
#
#
# [[33]]
# [[33]]$semilla
# [1] 841103
#
# [[33]]$testing
# [1] 49385
#
# [[33]]$testing_pos
# [1] 377
#
# [[33]]$envios
# [1] 3430
#
# [[33]]$aciertos
# [1] 203
#
# [[33]]$ganancia_test
# [1] 46900000
#
#
# [[34]]
# [[34]]$semilla
# [1] 958123
#
# [[34]]$testing
# [1] 49383
#
# [[34]]$testing_pos
# [1] 371
#
# [[34]]$envios
# [1] 3651
#
# [[34]]$aciertos
# [1] 221
#
# [[34]]$ganancia_test
# [1] 51890000
#
#
# [[35]]
# [[35]]$semilla
# [1] 548213
#
# [[35]]$testing
# [1] 49379
#
# [[35]]$testing_pos
# [1] 374
#
# [[35]]$envios
# [1] 3027
#
# [[35]]$aciertos
# [1] 187
#
# [[35]]$ganancia_test
# [1] 44530000
#
#
# [[36]]
# [[36]]$semilla
# [1] 678077
#
# [[36]]$testing
# [1] 49382
#
# [[36]]$testing_pos
# [1] 370
#
# [[36]]$envios
# [1] 4075
#
# [[36]]$aciertos
# [1] 206
#
# [[36]]$ganancia_test
# [1] 41650000
#
#
# [[37]]
# [[37]]$semilla
# [1] 525257
#
# [[37]]$testing
# [1] 49373
#
# [[37]]$testing_pos
# [1] 374
#
# [[37]]$envios
# [1] 3619
#
# [[37]]$aciertos
# [1] 210
#
# [[37]]$ganancia_test
# [1] 47810000
#
#
# [[38]]
# [[38]]$semilla
# [1] 198593
#
# [[38]]$testing
# [1] 49390
#
# [[38]]$testing_pos
# [1] 377
#
# [[38]]$envios
# [1] 3393
#
# [[38]]$aciertos
# [1] 212
#
# [[38]]$ganancia_test
# [1] 50870000
#
#
# [[39]]
# [[39]]$semilla
# [1] 190579
#
# [[39]]$testing
# [1] 49387
#
# [[39]]$testing_pos
# [1] 377
#
# [[39]]$envios
# [1] 3018
#
# [[39]]$aciertos
# [1] 201
#
# [[39]]$ganancia_test
# [1] 50220000
#
#
# [[40]]
# [[40]]$semilla
# [1] 515941
#
# [[40]]$testing
# [1] 49367
#
# [[40]]$testing_pos
# [1] 370
#
# [[40]]$envios
# [1] 3230
#
# [[40]]$aciertos
# [1] 194
#
# [[40]]$ganancia_test
# [1] 45300000
#
#
# [[41]]
# [[41]]$semilla
# [1] 996311
#
# [[41]]$testing
# [1] 49376
#
# [[41]]$testing_pos
# [1] 370
#
# [[41]]$envios
# [1] 3064
#
# [[41]]$aciertos
# [1] 193
#
# [[41]]$ganancia_test
# [1] 46560000
#
#
# [[42]]
# [[42]]$semilla
# [1] 693097
#
# [[42]]$testing
# [1] 49367
#
# [[42]]$testing_pos
# [1] 373
#
# [[42]]$envios
# [1] 3040
#
# [[42]]$aciertos
# [1] 209
#
# [[42]]$ganancia_test
# [1] 53200000
#
#
# [[43]]
# [[43]]$semilla
# [1] 603103
#
# [[43]]$testing
# [1] 49377
#
# [[43]]$testing_pos
# [1] 372
#
# [[43]]$envios
# [1] 2930
#
# [[43]]$aciertos
# [1] 182
#
# [[43]]$ganancia_test
# [1] 43500000
#
#
# [[44]]
# [[44]]$semilla
# [1] 341333
#
# [[44]]$testing
# [1] 49372
#
# [[44]]$testing_pos
# [1] 373
#
# [[44]]$envios
# [1] 3806
#
# [[44]]$aciertos
# [1] 213
#
# [[44]]$ganancia_test
# [1] 47140000
#
#
# [[45]]
# [[45]]$semilla
# [1] 578021
#
# [[45]]$testing
# [1] 49399
#
# [[45]]$testing_pos
# [1] 380
#
# [[45]]$envios
# [1] 3226
#
# [[45]]$aciertos
# [1] 212
#
# [[45]]$ganancia_test
# [1] 52540000
#
#
# [[46]]
# [[46]]$semilla
# [1] 702817
#
# [[46]]$testing
# [1] 49384
#
# [[46]]$testing_pos
# [1] 374
#
# [[46]]$envios
# [1] 3848
#
# [[46]]$aciertos
# [1] 222
#
# [[46]]$ganancia_test
# [1] 50320000
#
#
# [[47]]
# [[47]]$semilla
# [1] 343901
#
# [[47]]$testing
# [1] 49383
#
# [[47]]$testing_pos
# [1] 378
#
# [[47]]$envios
# [1] 3312
#
# [[47]]$aciertos
# [1] 199
#
# [[47]]$ganancia_test
# [1] 46480000
#
#
# [[48]]
# [[48]]$semilla
# [1] 122503
#
# [[48]]$testing
# [1] 49371
#
# [[48]]$testing_pos
# [1] 373
#
# [[48]]$envios
# [1] 3684
#
# [[48]]$aciertos
# [1] 215
#
# [[48]]$ganancia_test
# [1] 49160000
#
#
# [[49]]
# [[49]]$semilla
# [1] 705389
#
# [[49]]$testing
# [1] 49383
#
# [[49]]$testing_pos
# [1] 375
#
# [[49]]$envios
# [1] 3169
#
# [[49]]$aciertos
# [1] 217
#
# [[49]]$ganancia_test
# [1] 55110000
#
#
# [[50]]
# [[50]]$semilla
# [1] 276449
#
# [[50]]$testing
# [1] 49387
#
# [[50]]$testing_pos
# [1] 381
#
# [[50]]$envios
# [1] 2840
#
# [[50]]$aciertos
# [1] 207
#
# [[50]]$ganancia_test
# [1] 54400000
#
#
# [[51]]
# [[51]]$semilla
# [1] 530177
#
# [[51]]$testing
# [1] 49380
#
# [[51]]$testing_pos
# [1] 375
#
# [[51]]$envios
# [1] 2607
#
# [[51]]$aciertos
# [1] 174
#
# [[51]]$ganancia_test
# [1] 43530000
#
#
# [[52]]
# [[52]]$semilla
# [1] 216901
#
# [[52]]$testing
# [1] 49379
#
# [[52]]$testing_pos
# [1] 374
#
# [[52]]$envios
# [1] 3724
#
# [[52]]$aciertos
# [1] 197
#
# [[52]]$ganancia_test
# [1] 41560000
#
#
# [[53]]
# [[53]]$semilla
# [1] 934891
#
# [[53]]$testing
# [1] 49378
#
# [[53]]$testing_pos
# [1] 373
#
# [[53]]$envios
# [1] 2959
#
# [[53]]$aciertos
# [1] 196
#
# [[53]]$ganancia_test
# [1] 48810000
#
#
# [[54]]
# [[54]]$semilla
# [1] 550663
#
# [[54]]$testing
# [1] 49373
#
# [[54]]$testing_pos
# [1] 375
#
# [[54]]$envios
# [1] 3426
#
# [[54]]$aciertos
# [1] 217
#
# [[54]]$ganancia_test
# [1] 52540000
#
#
# [[55]]
# [[55]]$semilla
# [1] 107279
#
# [[55]]$testing
# [1] 49382
#
# [[55]]$testing_pos
# [1] 374
#
# [[55]]$envios
# [1] 2823
#
# [[55]]$aciertos
# [1] 185
#
# [[55]]$ganancia_test
# [1] 45770000
#
#
# [[56]]
# [[56]]$semilla
# [1] 123457
#
# [[56]]$testing
# [1] 49382
#
# [[56]]$testing_pos
# [1] 377
#
# [[56]]$envios
# [1] 3371
#
# [[56]]$aciertos
# [1] 194
#
# [[56]]$ganancia_test
# [1] 43890000
#
#
# [[57]]
# [[57]]$semilla
# [1] 800549
#
# [[57]]$testing
# [1] 49379
#
# [[57]]$testing_pos
# [1] 370
#
# [[57]]$envios
# [1] 2752
#
# [[57]]$aciertos
# [1] 187
#
# [[57]]$ganancia_test
# [1] 47280000
#
#
# [[58]]
# [[58]]$semilla
# [1] 308101
#
# [[58]]$testing
# [1] 49369
#
# [[58]]$testing_pos
# [1] 368
#
# [[58]]$envios
# [1] 3217
#
# [[58]]$aciertos
# [1] 193
#
# [[58]]$ganancia_test
# [1] 45030000
#
#
# [[59]]
# [[59]]$semilla
# [1] 397549
#
# [[59]]$testing
# [1] 49371
#
# [[59]]$testing_pos
# [1] 371
#
# [[59]]$envios
# [1] 3630
#
# [[59]]$aciertos
# [1] 215
#
# [[59]]$ganancia_test
# [1] 49700000
#
#
# [[60]]
# [[60]]$semilla
# [1] 441713
#
# [[60]]$testing
# [1] 49371
#
# [[60]]$testing_pos
# [1] 371
#
# [[60]]$envios
# [1] 3488
#
# [[60]]$aciertos
# [1] 218
#
# [[60]]$ganancia_test
# [1] 52320000
#
#
# [[61]]
# [[61]]$semilla
# [1] 535169
#
# [[61]]$testing
# [1] 49372
#
# [[61]]$testing_pos
# [1] 375
#
# [[61]]$envios
# [1] 4127
#
# [[61]]$aciertos
# [1] 220
#
# [[61]]$ganancia_test
# [1] 46730000
#
#
# [[62]]
# [[62]]$semilla
# [1] 364451
#
# [[62]]$testing
# [1] 49384
#
# [[62]]$testing_pos
# [1] 376
#
# [[62]]$envios
# [1] 3556
#
# [[62]]$aciertos
# [1] 200
#
# [[62]]$ganancia_test
# [1] 44440000
#
#
# [[63]]
# [[63]]$semilla
# [1] 429901
#
# [[63]]$testing
# [1] 49385
#
# [[63]]$testing_pos
# [1] 372
#
# [[63]]$envios
# [1] 2998
#
# [[63]]$aciertos
# [1] 190
#
# [[63]]$ganancia_test
# [1] 46020000
#
#
# [[64]]
# [[64]]$semilla
# [1] 654587
#
# [[64]]$testing
# [1] 49380
#
# [[64]]$testing_pos
# [1] 374
#
# [[64]]$envios
# [1] 3674
#
# [[64]]$aciertos
# [1] 206
#
# [[64]]$ganancia_test
# [1] 45660000
#
#
# [[65]]
# [[65]]$semilla
# [1] 577457
#
# [[65]]$testing
# [1] 49380
#
# [[65]]$testing_pos
# [1] 378
#
# [[65]]$envios
# [1] 3572
#
# [[65]]$aciertos
# [1] 196
#
# [[65]]$ganancia_test
# [1] 42680000
#
#
# [[66]]
# [[66]]$semilla
# [1] 440329
#
# [[66]]$testing
# [1] 49400
#
# [[66]]$testing_pos
# [1] 382
#
# [[66]]$envios
# [1] 3418
#
# [[66]]$aciertos
# [1] 211
#
# [[66]]$ganancia_test
# [1] 50220000
#
#
# [[67]]
# [[67]]$semilla
# [1] 103471
#
# [[67]]$testing
# [1] 49383
#
# [[67]]$testing_pos
# [1] 377
#
# [[67]]$envios
# [1] 3365
#
# [[67]]$aciertos
# [1] 195
#
# [[67]]$ganancia_test
# [1] 44350000
#
#
# [[68]]
# [[68]]$semilla
# [1] 149297
#
# [[68]]$testing
# [1] 49381
#
# [[68]]$testing_pos
# [1] 369
#
# [[68]]$envios
# [1] 3261
#
# [[68]]$aciertos
# [1] 192
#
# [[68]]$ganancia_test
# [1] 44190000
#
#
# [[69]]
# [[69]]$semilla
# [1] 149759
#
# [[69]]$testing
# [1] 49383
#
# [[69]]$testing_pos
# [1] 375
#
# [[69]]$envios
# [1] 2750
#
# [[69]]$aciertos
# [1] 179
#
# [[69]]$ganancia_test
# [1] 44100000
#
#
# [[70]]
# [[70]]$semilla
# [1] 338993
#
# [[70]]$testing
# [1] 49374
#
# [[70]]$testing_pos
# [1] 369
#
# [[70]]$envios
# [1] 3614
#
# [[70]]$aciertos
# [1] 216
#
# [[70]]$ganancia_test
# [1] 50260000
#
#
# [[71]]
# [[71]]$semilla
# [1] 252079
#
# [[71]]$testing
# [1] 49378
#
# [[71]]$testing_pos
# [1] 374
#
# [[71]]$envios
# [1] 3188
#
# [[71]]$aciertos
# [1] 192
#
# [[71]]$ganancia_test
# [1] 44920000
#
#
# [[72]]
# [[72]]$semilla
# [1] 304903
#
# [[72]]$testing
# [1] 49373
#
# [[72]]$testing_pos
# [1] 373
#
# [[72]]$envios
# [1] 3465
#
# [[72]]$aciertos
# [1] 191
#
# [[72]]$ganancia_test
# [1] 41750000
#
#
# [[73]]
# [[73]]$semilla
# [1] 834133
#
# [[73]]$testing
# [1] 49375
#
# [[73]]$testing_pos
# [1] 377
#
# [[73]]$envios
# [1] 3300
#
# [[73]]$aciertos
# [1] 212
#
# [[73]]$ganancia_test
# [1] 51800000
#
#
# [[74]]
# [[74]]$semilla
# [1] 549013
#
# [[74]]$testing
# [1] 49378
#
# [[74]]$testing_pos
# [1] 374
#
# [[74]]$envios
# [1] 3628
#
# [[74]]$aciertos
# [1] 201
#
# [[74]]$ganancia_test
# [1] 44120000
#
#
# [[75]]
# [[75]]$semilla
# [1] 753143
#
# [[75]]$testing
# [1] 49371
#
# [[75]]$testing_pos
# [1] 375
#
# [[75]]$envios
# [1] 3646
#
# [[75]]$aciertos
# [1] 214
#
# [[75]]$ganancia_test
# [1] 49140000
#
#
# [[76]]
# [[76]]$semilla
# [1] 393287
#
# [[76]]$testing
# [1] 49388
#
# [[76]]$testing_pos
# [1] 380
#
# [[76]]$envios
# [1] 3247
#
# [[76]]$aciertos
# [1] 207
#
# [[76]]$ganancia_test
# [1] 50330000
#
#
# [[77]]
# [[77]]$semilla
# [1] 131627
#
# [[77]]$testing
# [1] 49370
#
# [[77]]$testing_pos
# [1] 375
#
# [[77]]$envios
# [1] 2979
#
# [[77]]$aciertos
# [1] 197
#
# [[77]]$ganancia_test
# [1] 49010000
#
#
# [[78]]
# [[78]]$semilla
# [1] 382267
#
# [[78]]$testing
# [1] 49373
#
# [[78]]$testing_pos
# [1] 371
#
# [[78]]$envios
# [1] 3259
#
# [[78]]$aciertos
# [1] 205
#
# [[78]]$ganancia_test
# [1] 49410000
#
#
# [[79]]
# [[79]]$semilla
# [1] 282287
#
# [[79]]$testing
# [1] 49387
#
# [[79]]$testing_pos
# [1] 377
#
# [[79]]$envios
# [1] 3429
#
# [[79]]$aciertos
# [1] 194
#
# [[79]]$ganancia_test
# [1] 43310000
#
#
# [[80]]
# [[80]]$semilla
# [1] 300649
#
# [[80]]$testing
# [1] 49374
#
# [[80]]$testing_pos
# [1] 369
#
# [[80]]$envios
# [1] 3521
#
# [[80]]$aciertos
# [1] 200
#
# [[80]]$ganancia_test
# [1] 44790000
#
#
# [[81]]
# [[81]]$semilla
# [1] 587051
#
# [[81]]$testing
# [1] 49380
#
# [[81]]$testing_pos
# [1] 377
#
# [[81]]$envios
# [1] 1924
#
# [[81]]$aciertos
# [1] 164
#
# [[81]]$ganancia_test
# [1] 46360000
#
#
# [[82]]
# [[82]]$semilla
# [1] 206749
#
# [[82]]$testing
# [1] 49375
#
# [[82]]$testing_pos
# [1] 372
#
# [[82]]$envios
# [1] 3214
#
# [[82]]$aciertos
# [1] 200
#
# [[82]]$ganancia_test
# [1] 47860000
#
#
# [[83]]
# [[83]]$semilla
# [1] 171427
#
# [[83]]$testing
# [1] 49379
#
# [[83]]$testing_pos
# [1] 376
#
# [[83]]$envios
# [1] 3425
#
# [[83]]$aciertos
# [1] 213
#
# [[83]]$ganancia_test
# [1] 50950000
#
#
# [[84]]
# [[84]]$semilla
# [1] 238331
#
# [[84]]$testing
# [1] 49397
#
# [[84]]$testing_pos
# [1] 377
#
# [[84]]$envios
# [1] 3106
#
# [[84]]$aciertos
# [1] 207
#
# [[84]]$ganancia_test
# [1] 51740000
#
#
# [[85]]
# [[85]]$semilla
# [1] 805523
#
# [[85]]$testing
# [1] 49380
#
# [[85]]$testing_pos
# [1] 376
#
# [[85]]$envios
# [1] 2836
#
# [[85]]$aciertos
# [1] 178
#
# [[85]]$ganancia_test
# [1] 42840000
#
#
# [[86]]
# [[86]]$semilla
# [1] 836107
#
# [[86]]$testing
# [1] 49381
#
# [[86]]$testing_pos
# [1] 379
#
# [[86]]$envios
# [1] 3049
#
# [[86]]$aciertos
# [1] 205
#
# [[86]]$ganancia_test
# [1] 51510000
#
#
# [[87]]
# [[87]]$semilla
# [1] 279863
#
# [[87]]$testing
# [1] 49373
#
# [[87]]$testing_pos
# [1] 375
#
# [[87]]$envios
# [1] 3661
#
# [[87]]$aciertos
# [1] 204
#
# [[87]]$ganancia_test
# [1] 44990000
#
#
# [[88]]
# [[88]]$semilla
# [1] 236461
#
# [[88]]$testing
# [1] 49369
#
# [[88]]$testing_pos
# [1] 369
#
# [[88]]$envios
# [1] 3438
#
# [[88]]$aciertos
# [1] 203
#
# [[88]]$ganancia_test
# [1] 46820000
#
#
# [[89]]
# [[89]]$semilla
# [1] 671123
#
# [[89]]$testing
# [1] 49381
#
# [[89]]$testing_pos
# [1] 376
#
# [[89]]$envios
# [1] 3957
#
# [[89]]$aciertos
# [1] 228
#
# [[89]]$ganancia_test
# [1] 51630000
#
#
# [[90]]
# [[90]]$semilla
# [1] 298853
#
# [[90]]$testing
# [1] 49379
#
# [[90]]$testing_pos
# [1] 375
#
# [[90]]$envios
# [1] 4321
#
# [[90]]$aciertos
# [1] 235
#
# [[90]]$ganancia_test
# [1] 50790000
#
#
# [[91]]
# [[91]]$semilla
# [1] 357779
#
# [[91]]$testing
# [1] 49369
#
# [[91]]$testing_pos
# [1] 369
#
# [[91]]$envios
# [1] 3395
#
# [[91]]$aciertos
# [1] 217
#
# [[91]]$ganancia_test
# [1] 52850000
#
#
# [[92]]
# [[92]]$semilla
# [1] 302723
#
# [[92]]$testing
# [1] 49386
#
# [[92]]$testing_pos
# [1] 377
#
# [[92]]$envios
# [1] 3437
#
# [[92]]$aciertos
# [1] 204
#
# [[92]]$ganancia_test
# [1] 47230000
#
#
# [[93]]
# [[93]]$semilla
# [1] 216877
#
# [[93]]$testing
# [1] 49384
#
# [[93]]$testing_pos
# [1] 375
#
# [[93]]$envios
# [1] 3523
#
# [[93]]$aciertos
# [1] 212
#
# [[93]]$ganancia_test
# [1] 49570000
#
#
# [[94]]
# [[94]]$semilla
# [1] 296347
#
# [[94]]$testing
# [1] 49391
#
# [[94]]$testing_pos
# [1] 374
#
# [[94]]$envios
# [1] 3298
#
# [[94]]$aciertos
# [1] 193
#
# [[94]]$ganancia_test
# [1] 44220000
#
#
# [[95]]
# [[95]]$semilla
# [1] 421691
#
# [[95]]$testing
# [1] 49375
#
# [[95]]$testing_pos
# [1] 368
#
# [[95]]$envios
# [1] 4014
#
# [[95]]$aciertos
# [1] 216
#
# [[95]]$ganancia_test
# [1] 46260000
#
#
# [[96]]
# [[96]]$semilla
# [1] 357103
#
# [[96]]$testing
# [1] 49373
#
# [[96]]$testing_pos
# [1] 372
#
# [[96]]$envios
# [1] 3332
#
# [[96]]$aciertos
# [1] 208
#
# [[96]]$ganancia_test
# [1] 49880000
#
#
# [[97]]
# [[97]]$semilla
# [1] 483757
#
# [[97]]$testing
# [1] 49378
#
# [[97]]$testing_pos
# [1] 376
#
# [[97]]$envios
# [1] 3626
#
# [[97]]$aciertos
# [1] 219
#
# [[97]]$ganancia_test
# [1] 51340000
#
#
# [[98]]
# [[98]]$semilla
# [1] 855641
#
# [[98]]$testing
# [1] 49363
#
# [[98]]$testing_pos
# [1] 366
#
# [[98]]$envios
# [1] 2543
#
# [[98]]$aciertos
# [1] 176
#
# [[98]]$ganancia_test
# [1] 44970000
#
#
# [[99]]
# [[99]]$semilla
# [1] 779329
#
# [[99]]$testing
# [1] 49381
#
# [[99]]$testing_pos
# [1] 375
#
# [[99]]$envios
# [1] 2935
#
# [[99]]$aciertos
# [1] 194
#
# [[99]]$ganancia_test
# [1] 48250000
#
#
# [[100]]
# [[100]]$semilla
# [1] 540203
#
# [[100]]$testing
# [1] 49379
#
# [[100]]$testing_pos
# [1] 376
#
# [[100]]$envios
# [1] 2770
#
# [[100]]$aciertos
# [1] 186
#
# [[100]]$ganancia_test
# [1] 46700000

# %%
# paso la lista a vector
tb_salida <- rbindlist(salidas)
print( tb_salida)
# Out:
#      semilla testing testing_pos envios aciertos ganancia_test
#        <int>   <int>       <int>  <int>    <int>         <num>
#   1:  452033   49384         376   4024      222      48560000
#   2:  855377   49376         370   2180      154      39800000
#   3:  214663   49370         373   4019      219      47410000
#   4:  842977   49372         371   3322      192      43580000
#   5:  764657   49383         371   3596      202      44840000
#   6:  141079   49378         375   4497      230      47030000
#   7:  549547   49381         376   3888      195      39120000
#   8:  431777   49395         384   3261      194      44990000
#   9:  781283   49369         370   2935      193      47850000
#  10:  585461   49377         373   4097      224      48630000
#  11:  748597   49401         381   3929      219      48310000
#  12:  595379   49377         374   3203      193      45170000
#  13:  802183   49378         370   3715      203      44050000
#  14:  225149   49379         371   2751      192      49290000
#  15:  225241   49393         379   3278      221      55620000
#  16:  379459   49376         379   4185      233      51350000
#  17:  992521   49366         373   4385      211      40550000
#  18:  333031   49380         379   4164      223      47560000
#  19:  233341   49381         380   3748      214      48120000
#  20:  519287   49386         376   2981      179      41790000
#  21:  357587   49380         373   3684      229      54760000
#  22:  230431   49374         379   2589      174      43710000
#  23:  504947   49374         375   3588      209      47720000
#  24:  930689   49378         377   3230      213      52900000
#  25:  742439   49377         371   3265      217      54150000
#  26:  361873   49378         373   3359      191      42810000
#  27:  219503   49375         373   3965      206      42750000
#  28:  922289   49365         371   4197      213      43230000
#  29:  978403   49383         375   2568      193      51520000
#  30:  453667   49376         378   4093      206      41470000
#  31:  435553   49382         371   2833      194      49270000
#  32:  245131   49388         373   3352      199      46080000
#  33:  841103   49385         377   3430      203      46900000
#  34:  958123   49383         371   3651      221      51890000
#  35:  548213   49379         374   3027      187      44530000
#  36:  678077   49382         370   4075      206      41650000
#  37:  525257   49373         374   3619      210      47810000
#  38:  198593   49390         377   3393      212      50870000
#  39:  190579   49387         377   3018      201      50220000
#  40:  515941   49367         370   3230      194      45300000
#  41:  996311   49376         370   3064      193      46560000
#  42:  693097   49367         373   3040      209      53200000
#  43:  603103   49377         372   2930      182      43500000
#  44:  341333   49372         373   3806      213      47140000
#  45:  578021   49399         380   3226      212      52540000
#  46:  702817   49384         374   3848      222      50320000
#  47:  343901   49383         378   3312      199      46480000
#  48:  122503   49371         373   3684      215      49160000
#  49:  705389   49383         375   3169      217      55110000
#  50:  276449   49387         381   2840      207      54400000
#  51:  530177   49380         375   2607      174      43530000
#  52:  216901   49379         374   3724      197      41560000
#  53:  934891   49378         373   2959      196      48810000
#  54:  550663   49373         375   3426      217      52540000
#  55:  107279   49382         374   2823      185      45770000
#  56:  123457   49382         377   3371      194      43890000
#  57:  800549   49379         370   2752      187      47280000
#  58:  308101   49369         368   3217      193      45030000
#  59:  397549   49371         371   3630      215      49700000
#  60:  441713   49371         371   3488      218      52320000
#  61:  535169   49372         375   4127      220      46730000
#  62:  364451   49384         376   3556      200      44440000
#  63:  429901   49385         372   2998      190      46020000
#  64:  654587   49380         374   3674      206      45660000
#  65:  577457   49380         378   3572      196      42680000
#  66:  440329   49400         382   3418      211      50220000
#  67:  103471   49383         377   3365      195      44350000
#  68:  149297   49381         369   3261      192      44190000
#  69:  149759   49383         375   2750      179      44100000
#  70:  338993   49374         369   3614      216      50260000
#  71:  252079   49378         374   3188      192      44920000
#  72:  304903   49373         373   3465      191      41750000
#  73:  834133   49375         377   3300      212      51800000
#  74:  549013   49378         374   3628      201      44120000
#  75:  753143   49371         375   3646      214      49140000
#  76:  393287   49388         380   3247      207      50330000
#  77:  131627   49370         375   2979      197      49010000
#  78:  382267   49373         371   3259      205      49410000
#  79:  282287   49387         377   3429      194      43310000
#  80:  300649   49374         369   3521      200      44790000
#  81:  587051   49380         377   1924      164      46360000
#  82:  206749   49375         372   3214      200      47860000
#  83:  171427   49379         376   3425      213      50950000
#  84:  238331   49397         377   3106      207      51740000
#  85:  805523   49380         376   2836      178      42840000
#  86:  836107   49381         379   3049      205      51510000
#  87:  279863   49373         375   3661      204      44990000
#  88:  236461   49369         369   3438      203      46820000
#  89:  671123   49381         376   3957      228      51630000
#  90:  298853   49379         375   4321      235      50790000
#  91:  357779   49369         369   3395      217      52850000
#  92:  302723   49386         377   3437      204      47230000
#  93:  216877   49384         375   3523      212      49570000
#  94:  296347   49391         374   3298      193      44220000
#  95:  421691   49375         368   4014      216      46260000
#  96:  357103   49373         372   3332      208      49880000
#  97:  483757   49378         376   3626      219      51340000
#  98:  855641   49363         366   2543      176      44970000
#  99:  779329   49381         375   2935      194      48250000
# 100:  540203   49379         376   2770      186      46700000
#      semilla testing testing_pos envios aciertos ganancia_test

# %%
# calulo la salida
for( i in seq(10, 100, 10) )
{
  cat( i, "\t", tb_salida[ 1:i, mean(ganancia_test)], "\n" )
}
# Out:
# 10 	 45181000
# 20 	 46181000
# 30 	 46621333
# 40 	 46829000
# 50 	 47431400
# 60 	 47366667
# 70 	 47152143
# 80 	 47115375
# 90 	 47274667
# 100 	 47359900

# %% [markdown]
# ### Acciones a realizar
# * Reportar la  los resultados en la planilla colaborativa hoja  **C2-nsem**
# * Se discutirá en clase la variabilidad de las distintas cantidades de semillas

# %% [markdown]
# ---

# %% [markdown]
# # 5  DiezMil -Monte Carlo Cross Validation
# ## Clase 02  Experimento 5

# %% [markdown]
# Mostrar a los estudiantes el resultado de un experimento en donde se ha corrido una Monte Carlo Cross Validation utilizando diez mil semillas y relacionar la cantidad de semillas con el resultado del Teorema Central del Límite
# <br>Los resultados se muestran en esta misma guia y se comentan en clase,Bajo ningún concepto se solicitará a l@s estudiantes hacer este experimento en clase ya que lleva varias horas en correr.

# %% [markdown]
# Aqui usted NO debe correr absolutamente nada, el experimento ya fue corrido por la cátedra y le muestra los resultados.

# %% [markdown]
# ## 5.1
# Estos resultados han sido corridos por la cátedra.
#
# ![Distribucion de las ganancias](https://storage.googleapis.com/open-courses/austral2025-af91/labo1r/C2_E5_distribucion.jpg)

# %% [markdown]
# ![salida](https://storage.googleapis.com/open-courses/austral2025-af91/labo1r/C2_E5_salida.jpg)

# %% [markdown]
# ![tabla](https://storage.googleapis.com/open-courses/austral2025-af91/labo1r/C2_E5_tabla.jpg)
#
#  2    ~    1,96  =  3605406.2 / 1836264.3
#
# Por el teorema central del límite, un aumento de 4 veces de la cantidad de registros que se promedian el desvio estandar disminuye 2 veces ,  raiz(4 ) = 2

# %% [markdown]
# ---

# %% [markdown]
# # 6 Comparando dos distintos  modelos
# ## Clase 02  Experimento 6

# %% [markdown]
# ## 6.1  Objetivos
# Presentar a los alumnos la dificultad que se presenta ante la comparación de dos modelos, uno posee un poder predictivo claramente mayor al otro.
# Comparación simple de media de ganancias, versus probabilidad que un modelo sea superior a otro.

# %% [markdown]
# ## 6.2 Introduccion
# Estos son los dos arboles de muy distinta profundidad.
# <br>¿Cuál de ellos es mejor? ¿Cuál elijo?
#
# | Hiperparámetro | Arbol 1 | Arbol 2 |
# | --- | --: |  ---: |
# | cp | -1 | -1 |
# |minsplit | 170 | 250 |
# |minbucket | 70 | 125 |
# |maxdepth | 7 | 20 |

# %% [markdown]
# ## 6.3 Codigo dos distintos modelos

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %% [markdown]
# El tiempo de corrida es de alrededor de 40 minutos

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection

# %% [markdown]
# * Instalacion de la libreria  rpart.plot  para dibujar el arbol
# * invocacion de las librerias  **data.table** y  **rpart**

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
require("parallel")

if (!require("primes")) install.packages("primes")
require("primes")

require("ggplot2")

# %% [markdown]
# ###  Accion a Realizar
# PARAM$semilla_primigenia  debe reemplazarse por SU primer semilla

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 102191
PARAM$qsemillas <- 20
PARAM$training_pct <- 70L     # entre 1 y 100

# %%
# los dos arboles
PARAM$rpart1 <- list (
  "cp" = -1,
  "minsplit" = 170,
  "minbucket" = 70,
  "maxdepth" = 7
)


PARAM$rpart2 <- list (
  "cp" = -1,
  "minsplit" = 250,
  "minbucket" = 125,
  "maxdepth" = 20
)

# %%
# particionar agrega una columna llamada fold a un dataset
#  que consiste en una particion estratificada segun agrupa

# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(
    data, division, agrupa = "",
    campo = "fold", start = 1, seed = NA) {
  if (!is.na(seed)) set.seed(seed)

  bloque <- unlist(mapply(function(x, y) {
    rep(y, x)
  }, division, seq(from = start, length.out = length(division))))

  data[, (campo) := sample(rep(bloque, ceiling(.N / length(bloque))))[1:.N],
    by = agrupa
  ]
}

# %%
DosArbolesEstimarGanancia <- function(semilla, training_pct, param_rpart1, param_rpart2) {

  # fuerzo impresion
  print( paste( semilla, Sys.time()) )
  flush.console()

  # particiono estratificadamente el dataset
  particionar(dataset,
    division = c(training_pct, 100L -training_pct),
    agrupa = "clase_ternaria",
    seed = semilla # aqui se usa SU semilla
  )

  # genero el modelo
  # predecir clase_ternaria a partir del resto
  modelo1 <- rpart("clase_ternaria ~ .",
    data = dataset[fold == 1], # fold==1  es training,  el 70% de los datos
    xval = 0,
    control = param_rpart1
  ) # aqui van los parametros del arbol

  # aplico el modelo a los datos de testing
  prediccion1 <- predict(modelo1, # el modelo que genere recien
    dataset[fold == 2], # fold==2  es testing, el 30% de los datos
    type = "prob"
  ) # type= "prob"  es que devuelva la probabilidad


  # calculo la ganancia en testing  qu es fold==2
  ganancia_test1 <- dataset[
    fold == 2,
    sum(ifelse(prediccion1[, "BAJA+2"] > 0.025,
      ifelse(clase_ternaria == "BAJA+2", 117000, -3000),
      0
    ))
  ]

  # escalo la ganancia como si fuera todo el dataset
  ganancia_test_normalizada1 <- ganancia_test1 / (( 100 - training_pct ) / 100 )

  modelo2 <- rpart("clase_ternaria ~ .",
    data = dataset[fold == 1], # fold==1  es training,  el 70% de los datos
    xval = 0,
    control = param_rpart2
  ) # aqui van los parametros del arbol

  # aplico el modelo a los datos de testing
  prediccion2 <- predict(modelo2, # el modelo que genere recien
    dataset[fold == 2], # fold==2  es testing, el 30% de los datos
    type = "prob"
  ) # type= "prob"  es que devuelva la probabilidad


  # calculo la ganancia en testing  qu es fold==2
  ganancia_test2 <- dataset[
    fold == 2,
    sum(ifelse(prediccion2[, "BAJA+2"] > 0.025,
      ifelse(clase_ternaria == "BAJA+2", 117000, -3000),
      0
    ))
  ]

  # escalo la ganancia como si fuera todo el dataset
  ganancia_test_normalizada2 <- ganancia_test2 / (( 100 - training_pct ) / 100 )

  return(list(
    "semilla" = semilla,
    "ganancia1" = ganancia_test_normalizada1,
    "ganancia2" = ganancia_test_normalizada2
  ))
}

# %%
# carpeta de trabajo
setwd("/content/buckets/b1/exp")
experimento <- "exp206"
dir.create(experimento, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %%
# lectura del dataset
dataset <- fread("/content/datasets/dataset_pequeno.csv")

# trabajo solo con los datos con clase, es decir 202107
dataset <- dataset[clase_ternaria != ""]

# %%
detectCores()

# %%
# genero numeros primos
primos <- generate_primes(min = 100000, max = 1000000)
set.seed(PARAM$semilla_primigenia) # inicializo

# me quedo con PARAM$qsemillas   semillas
PARAM$semillas <- sample(primos, PARAM$qsemillas )

# %%
# demora interminables 60 minutos en correr en Google Colab
Sys.time()

salidas <- mcmapply( DosArbolesEstimarGanancia,
  PARAM$semillas, # paso el vector de semillas
  MoreArgs = list(PARAM$training_pct, PARAM$rpart1, PARAM$rpart2), # aqui paso el segundo parametro
  SIMPLIFY = FALSE,
  mc.cores = detectCores()
)

Sys.time()

# %%
# paso la lista a vector
tb_salida <- rbindlist(salidas)
tb_salida

# %%
grafico <- ggplot( tb_salida, aes(x=ganancia1)) + geom_density(alpha=0.25, fill="green", color="green")  +
             geom_density(data=tb_salida, aes(x=ganancia2), fill="purple", color="purple",  alpha=0.10)

print(grafico)

# %%
# imprimo en un .pdf  que va a la carpeta del experimento
pdf("densidad_dos.pdf")
print(grafico)
dev.off()

# %%
print( tb_salida[ , list( "arbol1" = mean( ganancia1),  "arbol2" = mean(ganancia2) ) ] )

print( tb_salida[ , list( "prob( m1 > m2)" = sum(ganancia1 > ganancia2 )/ .N ) ]  )

# %% [markdown]
# ### Acciones a realizar
# * Reportar la  los resultados en la planilla colaborativa hoja  **C2-dosModelos**
# * ¿Todos los alumnos hubieran elegido el mismo modelo aun con 20 semillas?

# %% [markdown]
# ---

# %% [markdown]
# # 7 Comparando dos buenos  modelos
# ## Clase 02  Experimento 7

# %% [markdown]
# ## 7.1  Objetivos
# Presentar a los alumnos la dificultad que surge en la comparación de dos muy distintos, pero ambos buenos, modelos predictivos, y el costo computacional asociado a esa comparación
# <br>Comparación simple de media de ganancias, versus probabilidad que un modelo sea superior a otro.
# <br>Limitaciones de la MonteCarlo Cross Validation
# <br>Existencia del Test de Wilcoxon

# %% [markdown]
# ## 7.2 Introduccion
# Estos son los dos arboles de muy distinta profundidad.
# <br>¿Cuál de ellos es mejor? ¿Cuál elijo?
#
# | Hiperparámetro | Arbol 1 | Arbol 2 |
# | --- | --: |  ---: |
# | cp | -1 | -1 |
# |minsplit | 170 | 1900 |
# |minbucket | 70 | 800 |
# |maxdepth | 7 | 3 |

# %% [markdown]
# ## 7.3 Dos buenos modelos

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %% [markdown]
# El tiempo de corrida es de alrededor de 50 minutos

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection

# %% [markdown]
# * Instalacion de la libreria  rpart.plot  para dibujar el arbol
# * invocacion de las librerias  **data.table** y  **rpart**

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
require("parallel")

if (!require("primes")) install.packages("primes")
require("primes")

require("ggplot2")

# %% [markdown]
# ###  Accion a Realizar
# PARAM$semilla_primigenia  debe reemplazarse por SU primer semilla

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 102191
PARAM$qsemillas <- 50
PARAM$training_pct <- 70L     # entre 1 y 100

# %%
# los dos arboles
PARAM$rpart1 <- list (
  "cp" = -1,
  "minsplit" = 170,
  "minbucket" = 70,
  "maxdepth" = 7
)


PARAM$rpart2 <- list (
  "cp" = -1,
  "minsplit" = 1900,
  "minbucket" = 800,
  "maxdepth" = 3
)

# %%
# particionar agrega una columna llamada fold a un dataset
#  que consiste en una particion estratificada segun agrupa

# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(
    data, division, agrupa = "",
    campo = "fold", start = 1, seed = NA) {
  if (!is.na(seed)) set.seed(seed)

  bloque <- unlist(mapply(function(x, y) {
    rep(y, x)
  }, division, seq(from = start, length.out = length(division))))

  data[, (campo) := sample(rep(bloque, ceiling(.N / length(bloque))))[1:.N],
    by = agrupa
  ]
}

# %%
DosArbolesEstimarGanancia <- function(semilla, training_pct, param_rpart1, param_rpart2) {
  # fuerzo impresion
  print( paste( semilla, Sys.time()) )
  flush.console()

  # particiono estratificadamente el dataset
  particionar(dataset,
    division = c(training_pct, 100L -training_pct),
    agrupa = "clase_ternaria",
    seed = semilla # aqui se usa SU semilla
  )

  # genero el modelo
  # predecir clase_ternaria a partir del resto
  modelo1 <- rpart("clase_ternaria ~ .",
    data = dataset[fold == 1], # fold==1  es training,  el 70% de los datos
    xval = 0,
    control = param_rpart1
  ) # aqui van los parametros del arbol

  # aplico el modelo a los datos de testing
  prediccion1 <- predict(modelo1, # el modelo que genere recien
    dataset[fold == 2], # fold==2  es testing, el 30% de los datos
    type = "prob"
  ) # type= "prob"  es que devuelva la probabilidad


  # calculo la ganancia en testing  qu es fold==2
  ganancia_test1 <- dataset[
    fold == 2,
    sum(ifelse(prediccion1[, "BAJA+2"] > 0.025,
      ifelse(clase_ternaria == "BAJA+2", 117000, -3000),
      0
    ))
  ]

  # escalo la ganancia como si fuera todo el dataset
  ganancia_test_normalizada1 <- ganancia_test1 / (( 100 - training_pct ) / 100 )

  modelo2 <- rpart("clase_ternaria ~ .",
    data = dataset[fold == 1], # fold==1  es training,  el 70% de los datos
    xval = 0,
    control = param_rpart2
  ) # aqui van los parametros del arbol

  # aplico el modelo a los datos de testing
  prediccion2 <- predict(modelo2, # el modelo que genere recien
    dataset[fold == 2], # fold==2  es testing, el 30% de los datos
    type = "prob"
  ) # type= "prob"  es que devuelva la probabilidad


  # calculo la ganancia en testing  qu es fold==2
  ganancia_test2 <- dataset[
    fold == 2,
    sum(ifelse(prediccion2[, "BAJA+2"] > 0.025,
      ifelse(clase_ternaria == "BAJA+2", 117000, -3000),
      0
    ))
  ]

  # escalo la ganancia como si fuera todo el dataset
  ganancia_test_normalizada2 <- ganancia_test2 / (( 100 - training_pct ) / 100 )

  return(list(
    "semilla" = semilla,
    "ganancia1" = ganancia_test_normalizada1,
    "ganancia2" = ganancia_test_normalizada2
  ))
}

# %%
# carpeta de trabajo
setwd("/content/buckets/b1/exp")
experimento <- "exp206"
dir.create(experimento, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %%
# lectura del dataset
dataset <- fread("/content/datasets/dataset_pequeno.csv")

# trabajo solo con los datos con clase, es decir 202107
dataset <- dataset[clase_ternaria != ""]

# %%
# genero numeros primos
primos <- generate_primes(min = 100000, max = 1000000)
set.seed(PARAM$semilla_primigenia) # inicializo

# me quedo con PARAM$qsemillas   semillas
PARAM$semillas <- sample(primos, PARAM$qsemillas )

# %%
# la funcion mcmapply  llama a la funcion DosArbolesEstimarGanancia
#  tantas veces como valores tenga el vector  PARAM$semillas
Sys.time()

salidas <- mcmapply( DosArbolesEstimarGanancia,
  PARAM$semillas, # paso el vector de semillas
  MoreArgs = list(PARAM$training_pct, PARAM$rpart1, PARAM$rpart2), # aqui paso el segundo parametro
  SIMPLIFY = FALSE,
  mc.cores = detectCores()
)

Sys.time()

# %%
# paso la lista a vector
tb_salida <- rbindlist(salidas)
tb_salida

# %%
grafico <- ggplot( tb_salida, aes(x=ganancia1), fill="green", color="green") + geom_density(alpha=0.25)  +
             geom_density(data=tb_salida, aes(x=ganancia2), fill="purple", color="purple",  alpha=0.10)

print(grafico)

# %%
# imprimo en un .pdf  que va a la carpeta del experimento
pdf("densidad_dos.pdf")
print(grafico)
dev.off()

# %%
# medias de las ganancias
print( tb_salida[ , list( "arbol1" = mean( ganancia1),  "arbol2" = mean(ganancia2) ) ] )

# %%
# probabilidad que m1 sea mayor a m2
print( tb_salida[ , list( "prob( m1 > m2)" = sum(ganancia1 > ganancia2 )/ .N ) ]  )

# %% [markdown]
# ### Acciones a realizar
# * Reportar la  los resultados en la planilla colaborativa hoja  **C2-dosBuenos**

# %% [markdown]
# ---

# %% [markdown]
# # 8 Test de Wilcoxon
# ## Clase 02  Experimento 8

# %% [markdown]
# ## 8.1  Objetivos
#
# ¿Como calcular la cantidad mínima de semillas que hacen falta para tener cierta certeza que un modelo es superior a otro?

# %% [markdown]
# ## 8.2  Introduccion
#
# | Hiperparámetro | Arbol 1 | Arbol 2 |
# | --- | --: |  ---: |
# | cp | -1 | -1 |
# |minsplit | 170 | 250 |
# |minbucket | 70 | 125 |
# |maxdepth | 7 | 20 |
#
# <br>
# <br>
#
#
# | ordinal | semilla | ganancia1 | ganancia2 | p-value |
# | --- | --- |  --- |  --- |  --- |
# | 1 |378821 | 41,470,000 | 37,790,000 | 1.000 |
# | 2 | 964333  | 48,480,000  | 43,660,000 | 0.500 |
# | 3 | 187049 | 50,610,000 | 47,840,000 | 0.250 |
# | 4 | 205151 | 45,580,000 | 44,490,000 | 0.125 |
# | 5 | 813697 | 52,780,000 | 46,750,000 |  0.063 |
# | 6 | 344719 | 49,970,000 | 44,300,000 | 0.031 |
# |7 |127217  |52,810,000 | 42,840,000 |0.016 |
# | 8 | 464371 | 43,060,000 | 37,300,000 | 0.008 |
# | 9 | 645137 | 49,660,000 |43,730,000 | 0.004|

# %% [markdown]
# ## 8.3 Codigo Test de Wilcoxon

# %%
# 1 sola ganancia
wilcox.test(
  c(41470000),
  c(37790000),
  paired = TRUE
)

# %%
# 2 ganancias
wilcox.test(
  c(41470000, 48480000),
  c(37790000, 43660000),
  paired = TRUE
)

# %%
# 3 ganancias
wilcox.test(
  c(41470000, 48480000, 50610000),
  c(37790000, 43660000, 47840000),
  paired = TRUE
)

# %%
# 4 ganancias
wilcox.test(
  c(41470000, 48480000, 50610000, 45580000),
  c(37790000, 43660000, 47840000, 44490000),
  paired = TRUE
)

# %%
# 5 ganancias
wilcox.test(
  c(41470000, 48480000, 50610000, 45580000, 52780000),
  c(37790000, 43660000, 47840000, 44490000, 46750000),
  paired = TRUE
)

# %%
# 6 ganancias
wilcox.test(
  c(41470000, 48480000, 50610000, 45580000, 52780000, 49970000),
  c(37790000, 43660000, 47840000, 44490000, 46750000, 44300000),
  paired = TRUE
)

# %%
# Finalmente el p-value es  0.03125  < 0.05
# hicieron falta  SEIS semillas, seis ganancias, para
#   afirmar que el modelo 1 es superior al modelo 2

# 7 ganancias
wilcox.test(
  c(41470000, 48480000, 50610000, 45580000, 52780000, 49970000, 52810000),
  c(37790000, 43660000, 47840000, 44490000, 46750000, 44300000, 42840000),
  paired = TRUE
)

# %%
# 8 ganancias
wilcox.test(
  c(41470000, 48480000, 50610000, 45580000, 52780000, 49970000, 52810000, 43060000),
  c(37790000, 43660000, 47840000, 44490000, 46750000, 44300000, 42840000, 37300000),
  paired = TRUE
)

# %%
# 9 ganancias
wilcox.test(
  c(41470000, 48480000, 50610000, 45580000, 52780000, 49970000, 52810000, 43060000, 49660000),
  c(37790000, 43660000, 47840000, 44490000, 46750000, 44300000, 42840000, 37300000, 43730000),
  paired = TRUE
)

# %% [markdown]
# ---

# %% [markdown]
# # 9 Comparando automaticamente modelos con test de Wilcoxon
# ## Clase 02  Experimento 9

# %% [markdown]
# ## 9.1  Objetivos
#
# Proveer un script que permita comparar dos arboles de decisión con la librería rpart utilizando la menor cantidad de cómputo que permita el Test de Wilxcoxon

# %% [markdown]
# ## 9.2  Introduccion
#
# | Hiperparámetro | Arbol 1 | Arbol 2 |
# | --- | --- |  --- |
# | cp | -1 | -1 |
# |minsplit | 1050 | 650 |
# |minbucket | 550 | 300 |
# |maxdepth |67 | 6 |

# %% [markdown]
# ## 9.3 Codigo comparacion automatica Wilcoxon

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection

# %% [markdown]
# * Instalacion de la libreria  rpart.plot  para dibujar el arbol
# * invocacion de las librerias  **data.table** y  **rpart**

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
require("parallel")

if (!require("primes")) install.packages("primes")
require("primes")

require("ggplot2")

# %% [markdown]
# ###  Accion a Realizar
# PARAM$semilla_primigenia  debe reemplazarse por SU primer semilla

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 102191
PARAM$qsemillas_tope <- 50
PARAM$training_pct <- 70L     # entre 1 y 100

# %%
# los dos arboles
PARAM$rpart1 <- list (
  "cp" = -1,
  "minsplit" = 800,
  "minbucket" = 400,
  "maxdepth" = 7
)


PARAM$rpart2 <- list (
  "cp" = -1,
  "minsplit" = 650,
  "minbucket" = 300,
  "maxdepth" = 6
)

# %%
# particionar agrega una columna llamada fold a un dataset
#  que consiste en una particion estratificada segun agrupa

# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(
    data, division, agrupa = "",
    campo = "fold", start = 1, seed = NA) {
  if (!is.na(seed)) set.seed(seed)

  bloque <- unlist(mapply(function(x, y) {
    rep(y, x)
  }, division, seq(from = start, length.out = length(division))))

  data[, (campo) := sample(rep(bloque, ceiling(.N / length(bloque))))[1:.N],
    by = agrupa
  ]
}

# %%
DosArbolesEstimarGanancia <- function(semilla, training_pct, param_rpart1, param_rpart2) {
  # particiono estratificadamente el dataset
  particionar(dataset,
    division = c(training_pct, 100L -training_pct),
    agrupa = "clase_ternaria",
    seed = semilla # aqui se usa SU semilla
  )

  # genero el modelo
  # predecir clase_ternaria a partir del resto
  modelo1 <- rpart("clase_ternaria ~ .",
    data = dataset[fold == 1], # fold==1  es training,  el 70% de los datos
    xval = 0,
    control = param_rpart1
  ) # aqui van los parametros del arbol

  # aplico el modelo a los datos de testing
  prediccion1 <- predict(modelo1, # el modelo que genere recien
    dataset[fold == 2], # fold==2  es testing, el 30% de los datos
    type = "prob"
  ) # type= "prob"  es que devuelva la probabilidad


  # calculo la ganancia en testing  qu es fold==2
  ganancia_test1 <- dataset[
    fold == 2,
    sum(ifelse(prediccion1[, "BAJA+2"] > 0.025,
      ifelse(clase_ternaria == "BAJA+2", 117000, -3000),
      0
    ))
  ]

  # escalo la ganancia como si fuera todo el dataset
  ganancia_test_normalizada1 <- ganancia_test1 / (( 100 - training_pct ) / 100 )

  modelo2 <- rpart("clase_ternaria ~ .",
    data = dataset[fold == 1], # fold==1  es training,  el 70% de los datos
    xval = 0,
    control = param_rpart2
  ) # aqui van los parametros del arbol

  # aplico el modelo a los datos de testing
  prediccion2 <- predict(modelo2, # el modelo que genere recien
    dataset[fold == 2], # fold==2  es testing, el 30% de los datos
    type = "prob"
  ) # type= "prob"  es que devuelva la probabilidad


  # calculo la ganancia en testing  qu es fold==2
  ganancia_test2 <- dataset[
    fold == 2,
    sum(ifelse(prediccion2[, "BAJA+2"] > 0.025,
      ifelse(clase_ternaria == "BAJA+2", 117000, -3000),
      0
    ))
  ]

  # escalo la ganancia como si fuera todo el dataset
  ganancia_test_normalizada2 <- ganancia_test2 / (( 100 - training_pct ) / 100 )

  return(list(
    "semilla" = semilla,
    "ganancia1" = ganancia_test_normalizada1,
    "ganancia2" = ganancia_test_normalizada2
  ))
}

# %%
# 1  ->  el modelo 1 es mejor
# 2  ->  el modelo 2 es mejor
# 0  ->  No se pudo determinar con el tope de qsemillas_tope


MejorArbol <- function( qsemillas_tope, training_pct, param_rpart1, param_rpart2) {

  # genero numeros primos
  primos <- generate_primes(min = 100000, max = 1000000)
  set.seed(PARAM$semilla_primigenia) # inicializo
  # me quedo con PARAM$qsemillas   semillas
  semillas <- sample(primos, qsemillas_tope )

  pvalue <- 1.0
  isem <- 1
  vgan1 <- c() # almaceno ganancias del modelo1
  vgan2 <- c() # almaceno ganancias del modelo2

  while( (isem <= qsemillas_tope)  & (pvalue > 0.05) ) {

    res <- DosArbolesEstimarGanancia(
       semillas[ isem ],
       training_pct,
       param_rpart1,
       param_rpart2
    )

    vgan1 <- c( vgan1, res$ganancia1 )
    vgan2 <- c( vgan2, res$ganancia2 )

    wt <- wilcox.test( vgan1, vgan2, paired=TRUE )
    pvalue <- wt$p.value

    cat( isem, res$ganancia1, res$ganancia2, pvalue, "\n" )
    flush.console()
    isem <- isem + 1
  }

  out <- 0

  if( pvalue < 0.05 & mean(vgan1) > mean(vgan2)  )  out <- 1
  if( pvalue < 0.05 & mean(vgan1) < mean(vgan2)  )  out <- 2


  return( list( "out" = out,
    "qsemillas" = length(vgan1),
    "m1" = mean( vgan1 ),
    "m2" = mean( vgan2 )
   ) )
}

# %%
# carpeta de trabajo
setwd("/content/buckets/b1/exp")
experimento <- "exp209"
dir.create(experimento, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %%
# lectura del dataset
dataset <- fread("/content/datasets/dataset_pequeno.csv")

# trabajo solo con los datos con clase, es decir 202107
dataset <- dataset[clase_ternaria != ""]

# %%
Sys.time()

comparacion <- MejorArbol(
   PARAM$qsemillas_tope,
   PARAM$training_pct,
   PARAM$rpart1,
   PARAM$rpart2
 )


print( comparacion )

Sys.time()

# %% [markdown]
# ### Acciones a realizar
# * Reportar la  los resultados en la planilla colaborativa hoja  **C2-Wilcox**

# %% [markdown]
# ---
